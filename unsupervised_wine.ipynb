# %%
import numpy as np
import pandas as pd

# %%
from scipy.stats import zscore
from sklearn.preprocessing import Imputer
from sklearn.metrics import accuracy_score
import seaborn as sns
from scipy import stats
from sklearn import metrics
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import statsmodels.api as sm
# %matplotlib inline
from sklearn import model_selection, preprocessing 
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from patsy import dmatrices
from sklearn.neighbors import KNeighborsClassifier

# %%
from matplotlib.mlab import PCA

# %%
colnames = ['Class','Alcohol','Malic_acid','Ash','Alcalinity_of_ash','Magnesium','Total_phenols','Flavanoids','Nonflavanoid_phenols','Proanthocyanins','Color_intensity','Hue','diluted_wines','Proline']

# %%
len(colnames)
# Out:
# 14

# %%
data = pd.read_csv("winedata2.data", names= colnames)

# %%
data.head()
# Out:
#    Class  Alcohol  Malic_acid   Ash  Alcalinity_of_ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color_intensity   Hue  diluted_wines  Proline
# 0             5.64  1.04           3.92     1065
# 1             4.38  1.05           3.40     1050
# ...

# %%
a=data.Class

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
# Class                   178 non-null int64
# Alcohol                 178 non-null float64
# Malic_acid              178 non-null float64
# Ash                     178 non-null float64
# Alcalinity_of_ash       178 non-null float64
# Magnesium               178 non-null int64
# Total_phenols           178 non-null float64
# Flavanoids              178 non-null float64
# Nonflavanoid_phenols    178 non-null float64
# Proanthocyanins         178 non-null float64
# Color_intensity         178 non-null float64
# Hue                     178 non-null float64
# diluted_wines           178 non-null float64
# Proline                 178 non-null int64
# dtypes: float64(11), int64(3)
# memory usage: 19.5 KB

# %%
data.describe()
# Out:
#             Class     Alcohol  Malic_acid         Ash  Alcalinity_of_ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total_phenols  Flavanoids  Nonflavanoid_phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
data.corr()
# Out:
#                          Class   Alcohol  Malic_acid       Ash  \
# Class                 1.000000 -0.328222    0.437776 -0.049643
# Alcohol              -0.328222  1.000000    0.094397  0.211545
# Malic_acid            0.437776  0.094397    1.000000  0.164045
# Ash                  -0.049643  0.211545    0.164045  1.000000
# Alcalinity_of_ash     0.517859 -0.310235    0.288500  0.443367
# Magnesium            -0.209179  0.270798   -0.054575  0.286587
# Total_phenols        -0.719163  0.289101   -0.335167  0.128980
# Flavanoids           -0.847498  0.236815   -0.411007  0.115077
# Nonflavanoid_phenols  0.489109 -0.155929    0.292977  0.186230
# Proanthocyanins      -0.499130  0.136698   -0.220746  0.009652
# Color_intensity       0.265668  0.546364    0.248985  0.258887
# Hue                  -0.617369 -0.071747   -0.561296 -0.074667
# diluted_wines        -0.788230  0.072343   -0.368710  0.003911
# Proline              -0.633717  0.643720   -0.192011  0.223626
#
# ...

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (178, 14)

# %%
data_z = data.apply(zscore)
data_z
# Out:
#         Class   Alcohol  Malic_acid       Ash  Alcalinity_of_ash  Magnesium  \
# 0   -1.213944  1.518613   -0.562250  0.232053          -1.169593   1.913905
# 1   -1.213944  0.246290   -0.499413 -0.827996          -2.490847   0.018145
# 2   -1.213944  0.196879    0.021231  1.109334          -0.268738   0.088358
# 3   -1.213944  1.691550   -0.346811  0.487926          -0.809251   0.930918
# 4   -1.213944  0.295700    0.227694  1.840403           0.451946   1.281985
# 5   -1.213944  1.481555   -0.517367  0.305159          -1.289707   0.860705
# 6   -1.213944  1.716255   -0.418624  0.305159          -1.469878  -0.262708
# 7   -1.213944  1.308617   -0.167278  0.890014          -0.569023   1.492625
# 8   -1.213944  2.259772   -0.625086 -0.718336          -1.650049  -0.192495
# 9   -1.213944  1.061565   -0.885409 -0.352802          -1.049479  -0.122282
# 10  -1.213944  1.358028   -0.158301 -0.243142          -0.448909   0.369212
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=14)

# %%
principalComponents = pca.fit_transform(X = data_z)

# %%
print(pca.explained_variance_ratio_.cumsum())
# Out:
# [0.39542486 0.57378745 0.67707846 0.74335831 0.80603706 0.85409266
#  0.89364973 0.91865217 0.93969088 0.95842703 0.97455906 0.98661596
#  0.99587055 1.        ]

# %%
componentss=pd.DataFrame(data=principalComponents,columns=['p1','p2','p3','p4','p5','p6','p7','p8','p9','p10','p11','p12','p13','p14'])

# %%
newcomps=componentss.iloc[:,:5]
newcomps2=np.array(newcomps)
a2=np.array(a)

# %%
fram=[newcomps,a]

# %%
result=pd.concat(fram,axis=1)

# %%
testcomps2= newcomps.iloc[130:178,:]

# %%
atest=a.iloc[130:178]

# %%
from sklearn.tree import DecisionTreeClassifier

DTClassifier = DecisionTreeClassifier (max_depth=3, criterion = "gini",min_samples_split = 2, random_state = 0)
DTClassifier.fit (newcomps2,a2)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
predicted_labels = DTClassifier.predict(testcomps2)

# %%
score = accuracy_score(atest, predicted_labels)
print(score)
# Out:
# 1.0

# %%
quick.elbow(, low = 0.08, max.pc = 0.9)
# Out:
#   File "<ipython-input-128-51e5d04e8063>", line 1
#     quick.elbow(, low = 0.08, max.pc = 0.9)
#                 ^
# SyntaxError: invalid syntax
